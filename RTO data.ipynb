# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from IPython.display import display
import base64
import string
import re
from collections import Counter
from time import time
# from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stopwords
from nltk.corpus import stopwords

# %%
stopwords = stopwords.words('english')
sns.set_context('notebook')

# %%
data=pd.read_csv('inspection data.csv')
data1=pd.read_excel('RTO_details.xlsx')
# Out:
# C:\Users\sj\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.info()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605926 entries, 0 to 605925
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             605926 non-null  int64
#  1   KMS            593635 non-null  float64
#  2   SALE_DT        593658 non-null  object
#  3   REPORT_DT      593658 non-null  object
#  4   REPAIR_DT      593658 non-null  object
#  5   MODEL          593658 non-null  object
#  6   SUB_MODEL      151610 non-null  object
#  7   CMPL_DESC      605866 non-null  object
#  8   INVESTIGATION  605845 non-null  object
#  9   ACTION_TAKEN   605815 non-null  object
#  10  REG_NO         605831 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 50.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1135 entries, 0 to 1134
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RegNo   1135 non-null   object
#  1   Place   1135 non-null   object
#  2   State   1135 non-null   object
# dtypes: object(3)
# memory usage: 26.7+ KB

# %% [markdown]
# # join two tables

# %%
#to join two tables we need a common attribute create a common attribute 
data['REG_NO'][1][0:4]
# Out:
# 'HR38'

# %%
#split registration no. and save this data into other column.
data["RegNo"]= data["REG_NO"].str[0:4]

# %%
#merge two data 
df=pd.merge(data,data1,on='RegNo',how='left')

# %% [markdown]
# # clean data and remove unneccasry data

# %%
#check null values
print(df.shape)
print(df.isna().sum())
# Out:
# (608697, 14)
# id                    0
# KMS               12369
# SALE_DT           12346
# REPORT_DT         12346
# REPAIR_DT         12346
# MODEL             12346
# SUB_MODEL        456262
# CMPL_DESC            60
# INVESTIGATION        81
# ACTION_TAKEN        111
# REG_NO               95
# RegNo                95
# Place             58714
# State             58714
# dtype: int64

# %%
#here we can see total data  is 605926 and submodel has more null values are 454316 drop this column
df.drop(labels='SUB_MODEL',axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# id                   0
# KMS              12369
# SALE_DT          12346
# REPORT_DT        12346
# REPAIR_DT        12346
# MODEL            12346
# CMPL_DESC           60
# INVESTIGATION       81
# ACTION_TAKEN       111
# REG_NO              95
# RegNo               95
# Place            58714
# State            58714
# dtype: int64

# %%
#drop null values 
df.dropna(inplace=True)

# %%
#now our data  set is clean and check there is any duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.iloc[49:58]
# Out:
#     id       KMS     SALE_DT   REPORT_DT   REPAIR_DT       MODEL  \
# 49  50  120060.0  30-01-2016  02-02-2018  03-02-2018  4018TC-LPS
# 50  51  120060.0  30-01-2016  02-02-2018  03-02-2018  4018TC-LPS
# 51  52  120060.0  30-01-2016  02-02-2018  03-02-2018  4018TC-LPS
# 52  53  110384.0  14-02-2014  23-01-2018  29-01-2018  2518TC-LPK
# 53  54  110384.0  14-02-2014  23-01-2018  29-01-2018  2518TC-LPK
# 54  55  110384.0  14-02-2014  23-01-2018  29-01-2018  2518TC-LPK
# 55  56  110384.0  14-02-2014  23-01-2018  29-01-2018  2518TC-LPK
# 56  57  110384.0  14-02-2014  23-01-2018  29-01-2018  2518TC-LPK
# 57  58  110384.0  14-02-2014  23-01-2018  29-01-2018  2518TC-LPK
#
#                                             CMPL_DESC  \
# 49                                    GEAR BOX NOISY.
# 50                                    GEAR BOX NOISY.
# 51                                    GEAR BOX NOISY.
# 52  NOISE FROM THE GEAR BOX IN 2ND SPEED GEAR .CLU...
# 53  NOISE FROM THE GEAR BOX IN 2ND SPEED GEAR .CLU...
# 54  NOISE FROM THE GEAR BOX IN 2ND SPEED GEAR .CLU...
# 55  NOISE FROM THE GEAR BOX IN 2ND SPEED GEAR .CLU...
# 56  NOISE FROM THE GEAR BOX IN 2ND SPEED GEAR .CLU...
# 57  NOISE FROM THE GEAR BOX IN 2ND SPEED GEAR .CLU...
#
#                                         INVESTIGATION  \
# 49  AFTER CONFIRMING THE COMPLAINT WE DISMENTALLED...
# 50  AFTER CONFIRMING THE COMPLAINT WE DISMENTALLED...
# 51  AFTER CONFIRMING THE COMPLAINT WE DISMENTALLED...
# 52  NO EXTERNAL LEAKAGE FOUND FURTHER DISMANTLED T...
# 53  NO EXTERNAL LEAKAGE FOUND FURTHER DISMANTLED T...
# 54  NO EXTERNAL LEAKAGE FOUND FURTHER DISMANTLED T...
# 55  NO EXTERNAL LEAKAGE FOUND FURTHER DISMANTLED T...
# 56  NO EXTERNAL LEAKAGE FOUND FURTHER DISMANTLED T...
# 57  NO EXTERNAL LEAKAGE FOUND FURTHER DISMANTLED T...
#
#                                          ACTION_TAKEN      REG_NO RegNo  \
# 49   REPLACED ALL THE FAILED PARTS U/W.DEFER.TXT 0004  CG07AZ9097  CG07
# 50   REPLACED ALL THE FAILED PARTS U/W.DEFER.TXT 0004  CG07AZ9097  CG07
# 51   REPLACED ALL THE FAILED PARTS U/W.DEFER.TXT 0004  CG07AZ9097  CG07
# 52  REPLACED THE GEAR BOX DEFECTIVE PARTS WITH NEW...   KA42A2402  KA42
# 53  REPLACED THE GEAR BOX DEFECTIVE PARTS WITH NEW...   KA42A2402  KA42
# 54  REPLACED THE GEAR BOX DEFECTIVE PARTS WITH NEW...   KA42A2402  KA42
# 55  REPLACED THE GEAR BOX DEFECTIVE PARTS WITH NEW...   KA42A2402  KA42
# 56  REPLACED THE GEAR BOX DEFECTIVE PARTS WITH NEW...   KA42A2402  KA42
# 57  REPLACED THE GEAR BOX DEFECTIVE PARTS WITH NEW...   KA42A2402  KA42
#
#          Place         State
# 49        Durg  Chhattisgarh
# 50        Durg  Chhattisgarh
# 51        Durg  Chhattisgarh
# 52  Ramanagara     Karnataka
# 53  Ramanagara     Karnataka
# 54  Ramanagara     Karnataka
# 55  Ramanagara     Karnataka
# 56  Ramanagara     Karnataka
# 57  Ramanagara     Karnataka

# %%
#here we can see that many cars has same issues on same date but from different id, so we can drop id column and check how many duplicate rows are in dataset.
df1=df.drop(labels='id',axis=1)

# %%
print(df1.duplicated().sum())
print(df1.shape)
# Out:
# 469500
# (538477, 12)

# %%
#drop these duplicate values
df1.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (68977, 12)

# %%
#make a copy of dataset
df2=df1.copy()

# %%
#now extract years and months from sales,report and repair dataset
df2['salesyear'] = pd.DatetimeIndex(df2['SALE_DT']).year
df2['repairyear'] = pd.DatetimeIndex(df2['REPAIR_DT']).year
df2['reportyear'] = pd.DatetimeIndex(df2['REPORT_DT']).year

# %%
df2['salesmonth']=pd.DatetimeIndex(df2['SALE_DT']).month
df2['repairmonth']=pd.DatetimeIndex(df2['REPAIR_DT']).month
df2['reportmonth']=pd.DatetimeIndex(df2['REPORT_DT']).month

# %%
#drop sales repair and report date
df2.drop(labels=['REPORT_DT','SALE_DT','REPAIR_DT'],axis=1,inplace=True)

# %%
# Graph
# Plotting a Histogram
df2.MODEL.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Number of car model')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
# Graph
# Plotting a Histogram
df2.Place.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Number of places where car most register')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
sns.boxplot(df2['salesyear'],df2['salesmonth'])

# %%
sns.boxplot(df2['repairyear'],df2['repairmonth'])

# %%
sns.boxplot(df2['repairyear'],df2['repairmonth'])

# %%
sns.barplot(x="REG_NO", y="KMS", data=df2)

# %% [markdown]
# # remove some extra words

# %%
op=df2['ACTION_TAKEN'][22]
print(op)
# Out:
# AFFECTED PARTS REPLACED UNDER WARRANTY.DEFER.TXT 0008

# %%
df2['ACTION_TAKEN']=df2['ACTION_TAKEN'].str.split('.TXT',1).str[0]

# %%
op1=df2['CMPL_DESC'][608640]
print(op1)
# Out:
# ABNORMAL NOSE FROM GEAR BOX. SR NO. 2691D826UY4A1335

# %%
df2['CMPL_DESC']=df2['CMPL_DESC'].str.split('. SR',1).str[0]

# %%
from wordcloud import WordCloud as wc
from nltk.corpus import stopwords
eng_stopwords = set(stopwords.words("english"))

# %% [markdown]
# # NLP

# %%
# max stop words
num_stopwords = df2["CMPL_DESC"].apply(lambda x: len([w for w in str(x).lower().split() if w in eng_stopwords]))
num_stopwords_action = df2['ACTION_TAKEN'].apply(lambda x: len([w for w in str(x).lower().split() if w in eng_stopwords]))

print('max number of stopwords in complaint has {} and action has {}'.format(num_stopwords.max(),num_stopwords_action.max()))
# Out:
# max number of stopwords in complaint has 67 and action has 67

# %%
#max punctuations
num_punctuation =df2['CMPL_DESC'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]) )
num_punctuations_action =df2['ACTION_TAKEN'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]) )

print('max number of punctuations in complaint has {} and action has {}'.format(num_punctuation.max(),num_punctuations_action.max()))
# Out:
# max number of punctuations in complaint has 237 and action has 237

# %% [markdown]
# Remove stopwords and punctuation

# %%
sw = stopwords.words('english')
def stopwords(text):
    '''a function for removing the stopword'''
    # removing the stop words and lowercasing the selected words
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    # joining the list of words with space separator
    return " ".join(text)
#### punctuation

def remove_punctuation(text):
    '''a function for removing punctuation'''
    import string
    # replacing the punctuations with no space, 
    # which in effect deletes the punctuation marks 
    translator = str.maketrans('', '', string.punctuation)
    # return the text stripped of punctuation marks
    return text.translate(translator)

# %%
df2['CMPL_DESC'] = df2['CMPL_DESC'].apply(stopwords)
df2['ACTION_TAKEN']=df2['ACTION_TAKEN'].apply(stopwords)

# %%
df2['CMPL_DESC']=df2['CMPL_DESC'].apply(remove_punctuation)
df2['ACTION_TAKEN']=df2['CMPL_DESC'].apply(remove_punctuation)

# %% [markdown]
# # Generate word cloud

# %%
def generate_wordcloud(text): 
    wordcloud = wc(relative_scaling = 1.0,stopwords = eng_stopwords).generate(text)
    fig,ax = plt.subplots(1,1,figsize=(15,20))
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis("off")
    ax.margins(x=0, y=0)
    plt.show()

# %%
#complaint text 
text_complaint = ' '.join([text for text in df2['CMPL_DESC']])
print('Number of words in all_text:', len(text_complaint))
generate_wordcloud(text_complaint)
# Out:
# Number of words in all_text: 1711435

# %%
#action taken
all_text_Action=' '.join([text for text in df2['ACTION_TAKEN']])
print('Number of words in all_text:', len(all_text_Action))
generate_wordcloud(all_text_Action)
# Out:
# Number of words in all_text: 1711435

# %%
#now check how many cars have issues and actions are same 
# for safety copy this dataset into other
df3=df2.copy()

# %%
def split_it(x):
    '''x is a feature and text1 is a substring which we want'''
    m = re.search(text1, x)
    if m:
        return m.group()

# %%
#1.Gear box issue

# %%
text1='gear box'

# %%
#1.complaint
x='CMPL_DESC'

df3['gearbox']=df3[x].apply(split_it)

# %%
#2 action
x='ACTION_TAKEN'
#text1='parts replaced'
df3['gear_action_taken']=df3[x].apply(split_it)

# %%
df3['gearboxmatch'] = np.where(df3['gearbox'] == df3['gear_action_taken'], 'gear box',None )
gear_box = df3.loc[df3['gear_action_taken'] == 'gear box']

# %%
gear_box=gear_box.dropna()

# %%
gear_box
# Out:
#              KMS            MODEL  \
# 14      150723.0       2518TC-LPT
# 47      120060.0       4018TC-LPS
# 52      110384.0       2518TC-LPK
# 66      140796.0   2518TC-LPK-6X4
# 76      202522.0  3718TC-LPT-10X2
# ...          ...              ...
# 608583  295804.0       4018TC-LPS
# 608607  248575.0       2518TC-LPT
# 608629  247856.0   4923TC-LPS-6X4
# 608640  397102.0       3118TC-LPT
# 608657  333124.0       4018TC-LPS
#
#                                                 CMPL_DESC  \
# 14                                    assy gear box noisy
# 47                                         gear box noisy
# 52      noise gear box 2nd speed gear clutch system ch...
# 66      noise gear box gear slippage clutch system che...
# 76                                         gear box noisy
# ...                                                   ...
# 608583                                     gear box noisy
# 608607                                     gear box noisy
# 608629                                     gear box noisy
# 608640                             abnormal nose gear box
# 608657                                     gear box noisy
#
#                                             INVESTIGATION  \
# 14      VEHICLE CAME IN OUR WORKSHOP ASSY GEAR BOX NOI...
# 47      AFTER CONFIRMING THE COMPLAINT WE DISMENTALLED...
# 52      NO EXTERNAL LEAKAGE FOUND FURTHER DISMANTLED T...
# 66      CHECKED OK FURTHER REMOVED DISMANTLED THE GEAR...
# 76      AFTER CONFIRMING THE COMPLAINT BY ROAD TEST WE...
# ...                                                   ...
# 608583  ROLLER THRUST BEARING ARRANGEMENT ROTATED SEAT...
# 608607  WE CHECKED AND FOUND THAT DRIVE SHAFT ROLLER S...
# 608629  THE VEHICLE WAS REPORTED WITH COMP. GEAR BOX N...
# 608640  WE FOUND UNSUAL NOISE FROM GEAR BOX OIL QTY AN...
# 608657  VEHICLE WAS BREAK DOWN FOR COMPLAINT OF GEAR B...
#
#                                              ACTION_TAKEN      REG_NO RegNo  \
# 14                                    assy gear box noisy  UP15CT2727  UP15
# 47                                         gear box noisy  CG07AZ9097  CG07
# 52      noise gear box 2nd speed gear clutch system ch...   KA42A2402  KA42
# 66      noise gear box gear slippage clutch system che...   KA42A3929  KA42
# 76                                         gear box noisy  CG07AV2487  CG07
# ...                                                   ...         ...   ...
# 608583                                     gear box noisy  RJ19GE3445  RJ19
# 608607                                     gear box noisy  UP83AT7446  UP83
# 608629                                     gear box noisy  RJ02GB3462  RJ02
# 608640                             abnormal nose gear box  MP06HC7116  MP06
# 608657                                     gear box noisy  RJ19GE4371  RJ19
#
#                                                     Place           State  \
# 14      Meerut (UP15AT for taxis, UP15AG for governmen...   Uttar Pradesh
# 47                                                   Durg    Chhattisgarh
# 52                                             Ramanagara       Karnataka
# 66                                             Ramanagara       Karnataka
# 76                                                   Durg    Chhattisgarh
# ...                                                   ...             ...
# 608583                                            Jodhpur       Rajasthan
# 608607                                          Firozabad   Uttar Pradesh
# 608629                                              Alwar       Rajasthan
# 608640                                             Morena  Madhya Pradesh
# 608657                                            Jodhpur       Rajasthan
#
#         salesyear  repairyear  reportyear  salesmonth  repairmonth  \
# 14           2015        2017        2017           8           12
# 47           2016        2018        2018           1            3
# 52           2014        2018        2018           2            1
# 66           2015        2018        2018           3            1
# 76           2015        2018        2018           2            2
# ...           ...         ...         ...         ...          ...
# 608583       2015        2019        2019          10           10
# 608607       2015        2019        2019          11           12
# 608629       2016        2019        2019           6           10
# 608640       2015        2019        2019          10           10
# 608657       2015        2019        2019          12           10
#
#         reportmonth   gearbox gear_action_taken gearboxmatch
# 14               12  gear box          gear box     gear box
# 47                2  gear box          gear box     gear box
# 52                1  gear box          gear box     gear box
# 66               12  gear box          gear box     gear box
# 76               12  gear box          gear box     gear box
# ...             ...       ...               ...          ...
# 608583           10  gear box          gear box     gear box
# 608607           11  gear box          gear box     gear box
# 608629           10  gear box          gear box     gear box
# 608640           10  gear box          gear box     gear box
# 608657           10  gear box          gear box     gear box
#
# [21936 rows x 18 columns]

# %%
#here we can see 21936 data has issue with gear box and its solve
# Graph
# Plotting a Histogram
gear_box.MODEL.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title('Number of car model')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
# here same model has different issue.
# Plotting a Histogram
gear_box.REG_NO.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Number of car model')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
#here we can see  4018TCS-LPS has measure issue with gear box

# %%
# lets do with other issue 
text1='box noisy'

# %%
#1.complaint
x='CMPL_DESC'

df3['box_noisy']=df3[x].apply(split_it)

# %%
#2 action
x='ACTION_TAKEN'
df3['box_action_taken']=df3[x].apply(split_it)

# %%
df3['box_nosiy_match'] = np.where(df3['box_noisy'] == df3['box_action_taken'], 'box noisy',None )
box_noisy = df3.loc[df3['box_action_taken'] == 'box noisy']

# %%
box_noisy
# Out:
#              KMS            MODEL            CMPL_DESC  \
# 14      150723.0       2518TC-LPT  assy gear box noisy
# 47      120060.0       4018TC-LPS       gear box noisy
# 76      202522.0  3718TC-LPT-10X2       gear box noisy
# 128      67739.0         1613-LPT       gear box noisy
# 162     180887.0       3118TC-LPT       gear box noisy
# ...          ...              ...                  ...
# 608556  102542.0       4018TC-LPS       gear box noisy
# 608583  295804.0       4018TC-LPS       gear box noisy
# 608607  248575.0       2518TC-LPT       gear box noisy
# 608629  247856.0   4923TC-LPS-6X4       gear box noisy
# 608657  333124.0       4018TC-LPS       gear box noisy
#
#                                             INVESTIGATION  \
# 14      VEHICLE CAME IN OUR WORKSHOP ASSY GEAR BOX NOI...
# 47      AFTER CONFIRMING THE COMPLAINT WE DISMENTALLED...
# 76      AFTER CONFIRMING THE COMPLAINT BY ROAD TEST WE...
# 128     AFTER CONFIRMING THE COMPLAINT BY ROAD TEST WE...
# 162     VEHICLE REPORTED TO OUR WORKSHOP WITH COMPLAIN...
# ...                                                   ...
# 608556  IN THE INVESTIGATION WE REMOVE THE GEAR BOX FR...
# 608583  ROLLER THRUST BEARING ARRANGEMENT ROTATED SEAT...
# 608607  WE CHECKED AND FOUND THAT DRIVE SHAFT ROLLER S...
# 608629  THE VEHICLE WAS REPORTED WITH COMP. GEAR BOX N...
# 608657  VEHICLE WAS BREAK DOWN FOR COMPLAINT OF GEAR B...
#
#                ACTION_TAKEN      REG_NO RegNo  \
# 14      assy gear box noisy  UP15CT2727  UP15
# 47           gear box noisy  CG07AZ9097  CG07
# 76           gear box noisy  CG07AV2487  CG07
# 128          gear box noisy  CG07BB8385  CG07
# 162          gear box noisy  CG04HQ0265  CG04
# ...                     ...         ...   ...
# 608556       gear box noisy   HR56B6087  HR56
# 608583       gear box noisy  RJ19GE3445  RJ19
# 608607       gear box noisy  UP83AT7446  UP83
# 608629       gear box noisy  RJ02GB3462  RJ02
# 608657       gear box noisy  RJ19GE4371  RJ19
#
#                                                     Place          State  \
# 14      Meerut (UP15AT for taxis, UP15AG for governmen...  Uttar Pradesh
# 47                                                   Durg   Chhattisgarh
# 76                                                   Durg   Chhattisgarh
# 128                                                  Durg   Chhattisgarh
# 162                                                Raipur   Chhattisgarh
# ...                                                   ...            ...
# 608556                    Jind (commercial vehicles only)        Haryana
# 608583                                            Jodhpur      Rajasthan
# 608607                                          Firozabad  Uttar Pradesh
# 608629                                              Alwar      Rajasthan
# 608657                                            Jodhpur      Rajasthan
#
#         salesyear  ...  reportyear  salesmonth  repairmonth  reportmonth  \
# 14           2015  ...        2017           8           12           12
# 47           2016  ...        2018           1            3            2
# 76           2015  ...        2018           2            2           12
# 128          2016  ...        2018           7            2            2
# 162          2014  ...        2018          12            4            4
# ...           ...  ...         ...         ...          ...          ...
# 608556       2017  ...        2019           8           10           10
# 608583       2015  ...        2019          10           10           10
# 608607       2015  ...        2019          11           12           11
# 608629       2016  ...        2019           6           10           10
# 608657       2015  ...        2019          12           10           10
#
#           gearbox gear_action_taken gearboxmatch  box_noisy box_action_taken  \
# 14      box noisy          gear box     gear box  box noisy        box noisy
# 47      box noisy          gear box     gear box  box noisy        box noisy
# 76      box noisy          gear box     gear box  box noisy        box noisy
# 128     box noisy          gear box     gear box  box noisy        box noisy
# 162     box noisy          gear box     gear box  box noisy        box noisy
# ...           ...               ...          ...        ...              ...
# 608556  box noisy          gear box     gear box  box noisy        box noisy
# 608583  box noisy          gear box     gear box  box noisy        box noisy
# 608607  box noisy          gear box     gear box  box noisy        box noisy
# 608629  box noisy          gear box     gear box  box noisy        box noisy
# 608657  box noisy          gear box     gear box  box noisy        box noisy
#
#        box_nosiy_match
# 14           box noisy
# 47           box noisy
# 76           box noisy
# 128          box noisy
# 162          box noisy
# ...                ...
# 608556       box noisy
# 608583       box noisy
# 608607       box noisy
# 608629       box noisy
# 608657       box noisy
#
# [16663 rows x 21 columns]

# %%
# now again check which model has this issue most
# Plotting a Histogram
box_noisy.MODEL.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title('Number of car model')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
# here same model has different issue.
# Plotting a Histogram
df3.REG_NO.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Number of car model')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
# 3 issue 
text1='engine oil'

# %%
#1.complaint
x='CMPL_DESC'

df3['engine_oil']=df3[x].apply(split_it)

# %%
#2 action
x='ACTION_TAKEN'
df3['engine_action_taken']=df3[x].apply(split_it)

# %%
df3['engine_oil_match'] = np.where(df3['engine_oil'] == df3['engine_action_taken'], 'engine oil',None )
engine_oil = df3.loc[df3['engine_oil_match'] == 'engine oil']

# %%
engine_oil.dropna()
# Out:
#              KMS       MODEL  \
# 373     135211.0  1613TC-SFC
# 8825    289257.0  4018TC-LPS
# 9448    325116.0  4018TC-LPS
# 9619    245786.0  2518TC-LPT
# 13951   226210.0  4018TC-LPS
# ...          ...         ...
# 541808  330055.0  4018TC-LPS
# 544433  211193.0  3118TC-LPT
# 561060  160490.0  2518TC-LPT
# 595766  368688.0  4018TC-LPS
# 602285  397580.0  2518TC-LPT
#
#                                                 CMPL_DESC  \
# 373     engine noisy gear box noisy check quality quan...
# 8825           engine oil consumption high gear box noisy
# 9448           engine oil consumption high gear box noisy
# 9619           engine oil consumption high gear box noisy
# 13951          engine oil consumption high gear box noisy
# ...                                                   ...
# 541808         high engine oil consumption gear box noisy
# 544433                  gear box noisy engine oil leakage
# 561060         engine oil consumption high gear box noisy
# 595766                  engine oil leakage gear box noisy
# 602285                     engine oil leak gear box noisy
#
#                                             INVESTIGATION  \
# 373     WE REMOVED THE CYL HEAD WE FOUND THE CYLINDER ...
# 8825    WE RECEIVED THE VEHICLE WITH COMPLAIN OF ENGIN...
# 9448    WE ATTEND THE VEHICLE WITH COMPLAIN OF ENGINE ...
# 9619    WE ATTEND THE VEHICLE WITH COMPLAIN OF ENGINE ...
# 13951   FIRST OF ALL CHECK THE VHEICLE AND FOUND THAT ...
# ...                                                   ...
# 541808  WE ATTEND VEHICLE WITH COMPLAINT ENGINE OIL CO...
# 544433  AT THE TIME OF INVESTIGATION WE HAVE FOUND THA...
# 561060  WE ATTEND VEHICLE WITH COMPLAINT HEOC WE CHECK...
# 595766  WE CHECK VEHICLE FOUND THAT CYLINDER HEAD GASK...
# 602285  WE CHECK THE VEHICLE AND FOUND OIL LEAK FROM T...
#
#                                              ACTION_TAKEN      REG_NO RegNo  \
# 373     engine noisy gear box noisy check quality quan...  JH10AV5093  JH10
# 8825           engine oil consumption high gear box noisy  RJ08GA3041  RJ08
# 9448           engine oil consumption high gear box noisy  RJ08GA2998  RJ08
# 9619           engine oil consumption high gear box noisy  RJ08GB1341  RJ08
# 13951          engine oil consumption high gear box noisy  RJ07GC0980  RJ07
# ...                                                   ...         ...   ...
# 541808         high engine oil consumption gear box noisy  RJ08GA3672  RJ08
# 544433                  gear box noisy engine oil leakage  AS01GC4511  AS01
# 561060         engine oil consumption high gear box noisy  RJ20GB2225  RJ20
# 595766                  engine oil leakage gear box noisy  RJ09GB4322  RJ09
# 602285                     engine oil leak gear box noisy   HR63C0780  HR63
#
#                                      Place      State  salesyear  ...  \
# 373                                Dhanbad  Jharkhand       2015  ...
# 8825                                 Bundi  Rajasthan       2014  ...
# 9448                                 Bundi  Rajasthan       2014  ...
# 9619                                 Bundi  Rajasthan       2015  ...
# 13951                              Bikaner  Rajasthan       2015  ...
# ...                                    ...        ...        ...  ...
# 541808                               Bundi  Rajasthan       2016  ...
# 544433                    Guwahati, Kamrup      Assam       2015  ...
# 561060                                Kota  Rajasthan       2016  ...
# 595766                        Chittaurgarh  Rajasthan       2016  ...
# 602285  Jhajjar (commercial vehicles only)    Haryana       2015  ...
#
#         reportmonth    gearbox  gear_action_taken  gearboxmatch   box_noisy  \
# 373              11  box noisy           gear box      gear box  engine oil
# 8825              7  box noisy           gear box      gear box  engine oil
# 9448              7  box noisy           gear box      gear box  engine oil
# 9619              7  box noisy           gear box      gear box  engine oil
# 13951             7  box noisy           gear box      gear box  engine oil
# ...             ...        ...                ...           ...         ...
# 541808            6  box noisy           gear box      gear box  engine oil
# 544433            6  box noisy           gear box      gear box  engine oil
# 561060            7  box noisy           gear box      gear box  engine oil
# 595766            7  box noisy           gear box      gear box  engine oil
# 602285           12  box noisy           gear box      gear box  engine oil
#
#        box_action_taken box_nosiy_match  engine_oil engine_action_taken  \
# 373           box noisy       box noisy  engine oil          engine oil
# 8825          box noisy       box noisy  engine oil          engine oil
# 9448          box noisy       box noisy  engine oil          engine oil
# 9619          box noisy       box noisy  engine oil          engine oil
# 13951         box noisy       box noisy  engine oil          engine oil
# ...                 ...             ...         ...                 ...
# 541808        box noisy       box noisy  engine oil          engine oil
# 544433        box noisy       box noisy  engine oil          engine oil
# 561060        box noisy       box noisy  engine oil          engine oil
# 595766        box noisy       box noisy  engine oil          engine oil
# 602285        box noisy       box noisy  engine oil          engine oil
#
#        engine_oil_match
# 373          engine oil
# 8825         engine oil
# 9448         engine oil
# 9619         engine oil
# 13951        engine oil
# ...                 ...
# 541808       engine oil
# 544433       engine oil
# 561060       engine oil
# 595766       engine oil
# 602285       engine oil
#
# [91 rows x 24 columns]

# %%
#91 data of problem with engine oil
# now again check which model has this issue most
# Plotting a Histogram
engine_oil.MODEL.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title('Number of car model')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
# now again check which model has this issue most
# Plotting a Histogram
engine_oil.REG_NO.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title('Number of car model')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
# this is how we can see that many cars has several issues but most common issue is gear box and noisy box.
